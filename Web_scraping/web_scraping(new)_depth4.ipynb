# %%
import requests
from bs4 import BeautifulSoup
import networkx as nx
from urllib.parse import urljoin

# Initialize graph and visited set
G = nx.Graph()
visited = set()

# %%
def strict_wiki_scraper(start_url, max_depth=1):
    G = nx.Graph()
    visited = set()

    def scrape(url, depth=0):
        if depth > max_depth or url in visited:
            return

        visited.add(url)
        print(f"Scraping (depth {depth}): {url}")

        try:
            response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
            soup = BeautifulSoup(response.text, 'html.parser')

            # Strict content selection
            content_div = soup.find('div', id='mw-content-text')
            if not content_div:
                return

            # Get the immediate child div (skips any metadata)
            main_content = content_div.find('div', recursive=False)
            if not main_content:
                return

            current_page = url.split('/wiki/')[-1]
            G.add_node(current_page)


            # Select only links from paragraphs and lists
            for element in main_content.find_all(['p', 'ul', 'ol'], recursive=False):
                for link in element.find_all('a', href=True):

                    href = link['href']

                    # Strict filtering
                    if (href.startswith('/wiki/') 
                        and ':' not in href
                        and not href.startswith(('/wiki/Main_Page', '/wiki/Special:'))):

                        full_url = urljoin("https://en.wikipedia.org", href)
                        linked_page = href.split('/wiki/')[-1]

                        G.add_node(linked_page)
                        G.add_edge(current_page, linked_page)

                        if depth < max_depth:
                            scrape(full_url, depth + 1)

        except Exception as e:
            print(f"Error scraping {url}: {e}")

    scrape(start_url)
    return G

# %%
start_url = "https://en.wikipedia.org/wiki/Sphenoidal_lingula"
max_depth = 4
graph = strict_wiki_scraper(start_url, max_depth)
print(f"Graph created with {len(graph.nodes())} nodes and {len(graph.edges())} edges.")
# Out:
# Scraping (depth 0): https://en.wikipedia.org/wiki/Sphenoidal_lingula
# Scraping (depth 1): https://en.wikipedia.org/wiki/Carotid_groove
# Scraping (depth 2): https://en.wikipedia.org/wiki/Sphenoid_bone
# Scraping (depth 3): https://en.wikipedia.org/wiki/Bone
# Scraping (depth 4): https://en.wikipedia.org/wiki/Stiffness
# Scraping (depth 4): https://en.wikipedia.org/wiki/Organ_(biology)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Skeleton
# Scraping (depth 4): https://en.wikipedia.org/wiki/Vertebrate
# Scraping (depth 4): https://en.wikipedia.org/wiki/Red_blood_cell
# Scraping (depth 4): https://en.wikipedia.org/wiki/White_blood_cell
# Scraping (depth 4): https://en.wikipedia.org/wiki/Mineral
# Scraping (depth 4): https://en.wikipedia.org/wiki/Animal_locomotion
# Scraping (depth 4): https://en.wikipedia.org/wiki/Function_(biology)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Mass_noun
# Scraping (depth 4): https://en.wikipedia.org/wiki/Hard_tissue
# Scraping (depth 4): https://en.wikipedia.org/wiki/Connective_tissue
# Scraping (depth 4): https://en.wikipedia.org/wiki/Honeycomb
# Scraping (depth 4): https://en.wikipedia.org/wiki/Matrix_(biology)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Bone_cell
# Scraping (depth 4): https://en.wikipedia.org/wiki/Osteoblast
# Scraping (depth 4): https://en.wikipedia.org/wiki/Osteocyte
# Scraping (depth 4): https://en.wikipedia.org/wiki/Mineralization_(biology)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Osteoclast
# Scraping (depth 4): https://en.wikipedia.org/wiki/Bone_resorption
# Scraping (depth 4): https://en.wikipedia.org/wiki/Collagen
# Scraping (depth 4): https://en.wikipedia.org/wiki/Ossein
# Scraping (depth 4): https://en.wikipedia.org/wiki/Bone_mineral
# Scraping (depth 4): https://en.wikipedia.org/wiki/Mineralized_tissues
# Scraping (depth 4): https://en.wikipedia.org/wiki/Bone_marrow
# Scraping (depth 4): https://en.wikipedia.org/wiki/Endosteum
# Scraping (depth 4): https://en.wikipedia.org/wiki/Periosteum
# Scraping (depth 4): https://en.wikipedia.org/wiki/Nerve
# Scraping (depth 4): https://en.wikipedia.org/wiki/Blood_vessel
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cartilage
# Scraping (depth 4): https://en.wikipedia.org/wiki/Human_body
# Scraping (depth 4): https://en.wikipedia.org/wiki/Sesamoid_bone
# Scraping (depth 4): https://en.wikipedia.org/wiki/Femur
# Scraping (depth 4): https://en.wikipedia.org/wiki/Stapes
# Scraping (depth 4): https://en.wikipedia.org/wiki/Middle_ear
# Scraping (depth 4): https://en.wikipedia.org/wiki/Ancient_Greek
# Scraping (depth 4): https://en.wikipedia.org/wiki/Osteopathy
# Scraping (depth 4): https://en.wikipedia.org/wiki/Anatomical_terminology
# Scraping (depth 4): https://en.wikipedia.org/wiki/Terminologia_Anatomica
# Scraping (depth 4): https://en.wikipedia.org/wiki/Short_bone
# Scraping (depth 4): https://en.wikipedia.org/wiki/Long_bone
# Scraping (depth 3): https://en.wikipedia.org/wiki/Neurocranium
# Scraping (depth 4): https://en.wikipedia.org/wiki/Skull#Humans
# Scraping (depth 4): https://en.wikipedia.org/wiki/Human_brain
# Scraping (depth 4): https://en.wikipedia.org/wiki/Calvaria_(skull)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Facial_skeleton
# Scraping (depth 4): https://en.wikipedia.org/wiki/Comparative_anatomy
# Scraping (depth 4): https://en.wikipedia.org/wiki/Endocranium
# Scraping (depth 4): https://en.wikipedia.org/wiki/Chondrocranium
# Scraping (depth 3): https://en.wikipedia.org/wiki/Skull
# Scraping (depth 3): https://en.wikipedia.org/wiki/Basilar_part_of_occipital_bone
# Scraping (depth 4): https://en.wikipedia.org/wiki/Occipital_bone
# Scraping (depth 4): https://en.wikipedia.org/wiki/Foramen_magnum
# Scraping (depth 3): https://en.wikipedia.org/wiki/Orbit_(anatomy)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Anatomy
# Scraping (depth 4): https://en.wikipedia.org/wiki/Body_cavity
# Scraping (depth 4): https://en.wikipedia.org/wiki/Eye
# Scraping (depth 4): https://en.wikipedia.org/wiki/Accessory_visual_structures
# Scraping (depth 4): https://en.wikipedia.org/wiki/Orbital_fascia
# Scraping (depth 4): https://en.wikipedia.org/wiki/Retrobulbar
# Scraping (depth 4): https://en.wikipedia.org/wiki/Extraocular_muscles
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cranial_nerve
# Scraping (depth 4): https://en.wikipedia.org/wiki/Optic_nerve
# Scraping (depth 4): https://en.wikipedia.org/wiki/Oculomotor_nerve
# Scraping (depth 4): https://en.wikipedia.org/wiki/Trochlear_nerve
# Scraping (depth 4): https://en.wikipedia.org/wiki/Trigeminal_nerve
# Scraping (depth 4): https://en.wikipedia.org/wiki/Abducens_nerve
# Scraping (depth 4): https://en.wikipedia.org/wiki/Lacrimal_gland
# Scraping (depth 4): https://en.wikipedia.org/wiki/Lacrimal_sac
# Scraping (depth 4): https://en.wikipedia.org/wiki/Nasolacrimal_duct
# Scraping (depth 4): https://en.wikipedia.org/wiki/Eyelid
# Scraping (depth 4): https://en.wikipedia.org/wiki/Medial_palpebral_ligament
# Scraping (depth 4): https://en.wikipedia.org/wiki/Lateral_palpebral_raphe
# Scraping (depth 4): https://en.wikipedia.org/wiki/Zonule_of_Zinn
# Scraping (depth 4): https://en.wikipedia.org/wiki/Orbital_septum
# Scraping (depth 4): https://en.wikipedia.org/wiki/Ciliary_ganglion
# Scraping (depth 4): https://en.wikipedia.org/wiki/Short_ciliary_nerves
# Scraping (depth 3): https://en.wikipedia.org/wiki/Butterfly
# Scraping (depth 4): https://en.wikipedia.org/wiki/Winged_insects
# Scraping (depth 4): https://en.wikipedia.org/wiki/Lepidopteran
# Scraping (depth 4): https://en.wikipedia.org/wiki/Superfamily_(taxonomy)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Paleocene
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cretaceous
# Scraping (depth 4): https://en.wikipedia.org/wiki/Biological_life_cycle
# Scraping (depth 4): https://en.wikipedia.org/wiki/Holometabola
# Scraping (depth 4): https://en.wikipedia.org/wiki/Holometabolism
# Scraping (depth 4): https://en.wikipedia.org/wiki/Larva
# Scraping (depth 4): https://en.wikipedia.org/wiki/Caterpillar
# Scraping (depth 4): https://en.wikipedia.org/wiki/Pupa
# Scraping (depth 4): https://en.wikipedia.org/wiki/Chrysalis
# Scraping (depth 4): https://en.wikipedia.org/wiki/Metamorphosis
# Scraping (depth 4): https://en.wikipedia.org/wiki/Polymorphism_(biology)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Camouflage
# Scraping (depth 4): https://en.wikipedia.org/wiki/Mimicry
# Scraping (depth 4): https://en.wikipedia.org/wiki/Aposematism
# Scraping (depth 4): https://en.wikipedia.org/wiki/Monarch_butterfly
# Scraping (depth 4): https://en.wikipedia.org/wiki/Vanessa_cardui
# Scraping (depth 4): https://en.wikipedia.org/wiki/Insect_migration
# Scraping (depth 4): https://en.wikipedia.org/wiki/Parasite
# Scraping (depth 4): https://en.wikipedia.org/wiki/Parasitoid
# Scraping (depth 4): https://en.wikipedia.org/wiki/Parasitoid_wasp
# Scraping (depth 4): https://en.wikipedia.org/wiki/Protozoa
# Scraping (depth 4): https://en.wikipedia.org/wiki/Fly
# Scraping (depth 4): https://en.wikipedia.org/wiki/Predation
# Scraping (depth 4): https://en.wikipedia.org/wiki/Pollination
# Scraping (depth 4): https://en.wikipedia.org/wiki/Miletinae
# Scraping (depth 4): https://en.wikipedia.org/wiki/Ant
# Scraping (depth 4): https://en.wikipedia.org/wiki/Mutualism_(biology)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Smithsonian_Institution
# Scraping (depth 3): https://en.wikipedia.org/wiki/Bat
# Scraping (depth 3): https://en.wikipedia.org/wiki/Wasp
# Scraping (depth 4): https://en.wikipedia.org/wiki/Insect
# Scraping (depth 4): https://en.wikipedia.org/wiki/Apocrita
# Scraping (depth 4): https://en.wikipedia.org/wiki/Hymenoptera
# Scraping (depth 4): https://en.wikipedia.org/wiki/Bee
# Scraping (depth 4): https://en.wikipedia.org/wiki/Sawflies
# Scraping (depth 4): https://en.wikipedia.org/wiki/Clade
# Scraping (depth 4): https://en.wikipedia.org/wiki/Aculeata
# Scraping (depth 4): https://en.wikipedia.org/wiki/Stinger
# Scraping (depth 4): https://en.wikipedia.org/wiki/Yellowjacket
# Scraping (depth 4): https://en.wikipedia.org/wiki/Hornet
# Scraping (depth 4): https://en.wikipedia.org/wiki/Vespidae
# Scraping (depth 4): https://en.wikipedia.org/wiki/Eusociality
# Scraping (depth 4): https://en.wikipedia.org/wiki/Haplodiploid
# Scraping (depth 4): https://en.wikipedia.org/wiki/Sex-determination_system
# Scraping (depth 4): https://en.wikipedia.org/wiki/Ovipositor
# Scraping (depth 4): https://en.wikipedia.org/wiki/Sting_(biology)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Ecology
# Scraping (depth 4): https://en.wikipedia.org/wiki/Predator
# Scraping (depth 4): https://en.wikipedia.org/wiki/Pollinator
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cuckoo_wasp
# Scraping (depth 4): https://en.wikipedia.org/wiki/Kleptoparasite
# Scraping (depth 4): https://en.wikipedia.org/wiki/Mass_provisioning
# Scraping (depth 4): https://en.wikipedia.org/wiki/Host_(biology)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Pest_insect
# Scraping (depth 4): https://en.wikipedia.org/wiki/Horticulture
# Scraping (depth 4): https://en.wikipedia.org/wiki/Biological_pest_control
# Scraping (depth 4): https://en.wikipedia.org/wiki/Whitefly
# Scraping (depth 4): https://en.wikipedia.org/wiki/Tomato
# Scraping (depth 4): https://en.wikipedia.org/wiki/Jurassic
# Scraping (depth 4): https://en.wikipedia.org/wiki/Asian_giant_hornet
# Scraping (depth 4): https://en.wikipedia.org/wiki/Tarantula_hawk
# Scraping (depth 4): https://en.wikipedia.org/wiki/Megascolia_procer
# Scraping (depth 4): https://en.wikipedia.org/wiki/Mymaridae
# Scraping (depth 4): https://en.wikipedia.org/wiki/Classical_era
# Scraping (depth 4): https://en.wikipedia.org/wiki/Aristophanes
# Scraping (depth 4): https://en.wikipedia.org/wiki/The_Wasps
# Scraping (depth 4): https://en.wikipedia.org/wiki/Science_fiction
# Scraping (depth 4): https://en.wikipedia.org/wiki/H._G._Wells
# Scraping (depth 4): https://en.wikipedia.org/wiki/The_Food_of_the_Gods_and_How_It_Came_to_Earth
# Scraping (depth 2): https://en.wikipedia.org/wiki/Great_wing
# Scraping (depth 3): https://en.wikipedia.org/wiki/Human_eye
# Scraping (depth 3): https://en.wikipedia.org/wiki/Body_of_sphenoid_bone
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cube_(geometry)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Sphenoidal_sinus
# Scraping (depth 4): https://en.wikipedia.org/wiki/Septum
# Scraping (depth 2): https://en.wikipedia.org/wiki/Internal_carotid_artery
# Scraping (depth 3): https://en.wikipedia.org/wiki/Artery
# Scraping (depth 3): https://en.wikipedia.org/wiki/Neck
# Scraping (depth 4): https://en.wikipedia.org/wiki/Head_(anatomy)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Brain
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cervical_vertebrae
# Scraping (depth 4): https://en.wikipedia.org/wiki/Spinal_cord
# Scraping (depth 4): https://en.wikipedia.org/wiki/Respiratory_tract
# Scraping (depth 4): https://en.wikipedia.org/wiki/Gastrointestinal_tract
# Scraping (depth 4): https://en.wikipedia.org/wiki/Endocrine_gland
# Scraping (depth 4): https://en.wikipedia.org/wiki/Vein
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cervix
# Scraping (depth 4): https://en.wikipedia.org/wiki/Uterus
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cervical_lymph_nodes
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cervical_cap
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cervical_cancer
# Scraping (depth 3): https://en.wikipedia.org/wiki/Anterior_cerebral_artery
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cerebral_arteries
# Scraping (depth 4): https://en.wikipedia.org/wiki/Frontal_lobe
# Scraping (depth 4): https://en.wikipedia.org/wiki/Superior_medial_parietal
# Scraping (depth 4): https://en.wikipedia.org/wiki/Lobes_of_the_brain
# Scraping (depth 4): https://en.wikipedia.org/wiki/Circle_of_Willis
# Scraping (depth 4): https://en.wikipedia.org/wiki/Anterior_communicating_artery
# Scraping (depth 4): https://en.wikipedia.org/wiki/Anterior_cerebral_artery_syndrome
# Scraping (depth 4): https://en.wikipedia.org/wiki/Stroke
# Scraping (depth 4): https://en.wikipedia.org/wiki/Paresis
# Scraping (depth 3): https://en.wikipedia.org/wiki/Middle_cerebral_artery
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cerebral_artery
# Scraping (depth 4): https://en.wikipedia.org/wiki/Blood
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cerebrum
# Scraping (depth 4): https://en.wikipedia.org/wiki/Lateral_sulcus
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cerebral_cortex
# Scraping (depth 4): https://en.wikipedia.org/wiki/Temporal_lobe
# Scraping (depth 4): https://en.wikipedia.org/wiki/Insular_cortex
# Scraping (depth 4): https://en.wikipedia.org/wiki/Posterior_communicating_artery
# Scraping (depth 4): https://en.wikipedia.org/wiki/Posterior_cerebral_artery
# Scraping (depth 3): https://en.wikipedia.org/wiki/Cerebral_circulation
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cerebral_veins
# Scraping (depth 4): https://en.wikipedia.org/wiki/Blood_flow
# Scraping (depth 4): https://en.wikipedia.org/wiki/Human
# Scraping (depth 4): https://en.wikipedia.org/wiki/Milliliter
# Scraping (depth 4): https://en.wikipedia.org/wiki/Minute
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cardiac_output
# Scraping (depth 4): https://en.wikipedia.org/wiki/Oxidation
# Scraping (depth 4): https://en.wikipedia.org/wiki/Glucose
# Scraping (depth 4): https://en.wikipedia.org/wiki/Heart
# Scraping (depth 4): https://en.wikipedia.org/wiki/Carbon_dioxide
# Scraping (depth 4): https://en.wikipedia.org/wiki/Lactic_acid
# Scraping (depth 4): https://en.wikipedia.org/wiki/Metabolism
# Scraping (depth 4): https://en.wikipedia.org/wiki/Neurovascular_unit
# Scraping (depth 4): https://en.wikipedia.org/wiki/Autoregulation
# Scraping (depth 4): https://en.wikipedia.org/wiki/Volume
# Scraping (depth 4): https://en.wikipedia.org/wiki/G-force
# Scraping (depth 4): https://en.wikipedia.org/wiki/G-force#Human_tolerance
# Scraping (depth 4): https://en.wikipedia.org/wiki/Nomenclature
# Scraping (depth 3): https://en.wikipedia.org/wiki/External_carotid_artery
# Scraping (depth 4): https://en.wikipedia.org/wiki/Common_carotid_artery
# Scraping (depth 4): https://en.wikipedia.org/wiki/Superficial_temporal
# Scraping (depth 4): https://en.wikipedia.org/wiki/Maxillary_artery
# Scraping (depth 4): https://en.wikipedia.org/wiki/Parotid_gland
# Scraping (depth 3): https://en.wikipedia.org/wiki/Face
# Scraping (depth 3): https://en.wikipedia.org/wiki/Scalp
# Scraping (depth 3): https://en.wikipedia.org/wiki/Meninges
# Scraping (depth 4): https://en.wikipedia.org/wiki/Ancient_Greek_language
# Scraping (depth 4): https://en.wikipedia.org/wiki/Membrane
# Scraping (depth 4): https://en.wikipedia.org/wiki/Mammal
# Scraping (depth 4): https://en.wikipedia.org/wiki/Dura_mater
# Scraping (depth 4): https://en.wikipedia.org/wiki/Arachnoid_mater
# Scraping (depth 4): https://en.wikipedia.org/wiki/Pia_mater
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cerebrospinal_fluid
# Scraping (depth 4): https://en.wikipedia.org/wiki/Central_nervous_system
# Scraping (depth 2): https://en.wikipedia.org/wiki/Cavernous_sinus
# Scraping (depth 3): https://en.wikipedia.org/wiki/Dural_venous_sinuses
# Scraping (depth 4): https://en.wikipedia.org/wiki/Sinus_(anatomy)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Subarachnoid_space
# Scraping (depth 4): https://en.wikipedia.org/wiki/Arachnoid_granulations
# Scraping (depth 4): https://en.wikipedia.org/wiki/Internal_jugular_vein
# Scraping (depth 4): https://en.wikipedia.org/wiki/Venous_sinuses
# Scraping (depth 4): https://en.wikipedia.org/wiki/Emissary_veins
# Scraping (depth 3): https://en.wikipedia.org/wiki/Temporal_bone
# Scraping (depth 4): https://en.wikipedia.org/wiki/Temple_(anatomy)
# Scraping (depth 4): https://en.wikipedia.org/wiki/Temporal_muscle
# Scraping (depth 4): https://en.wikipedia.org/wiki/Ear
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cranial_nerves
# Scraping (depth 3): https://en.wikipedia.org/wiki/Human_skull
# Scraping (depth 3): https://en.wikipedia.org/wiki/Sella_turcica
# Scraping (depth 4): https://en.wikipedia.org/wiki/Latin
# Scraping (depth 4): https://en.wikipedia.org/wiki/Saddle
# Scraping (depth 4): https://en.wikipedia.org/wiki/Hominid
# Scraping (depth 4): https://en.wikipedia.org/wiki/Chimpanzee
# Scraping (depth 4): https://en.wikipedia.org/wiki/Gorilla
# Scraping (depth 4): https://en.wikipedia.org/wiki/Orangutan
# Scraping (depth 4): https://en.wikipedia.org/wiki/Cephalometric_analysis#Cephalometric_landmarks
# Scraping (depth 4): https://en.wikipedia.org/wiki/Pituitary_gland
# Scraping (depth 4): https://en.wikipedia.org/wiki/Fossa_(anatomy)
# Scraping (depth 2): https://en.wikipedia.org/wiki/Public_domain
# Scraping (depth 2): https://en.wikipedia.org/wiki/Gray%27s_Anatomy
# Scraping (depth 3): https://en.wikipedia.org/wiki/Human_anatomy
# Scraping (depth 3): https://en.wikipedia.org/wiki/Henry_Gray
# Scraping (depth 4): https://en.wikipedia.org/wiki/Fellow_of_the_Royal_Society
# Scraping (depth 4): https://en.wikipedia.org/wiki/Anatomist
# Scraping (depth 4): https://en.wikipedia.org/wiki/Surgery
# Scraping (depth 3): https://en.wikipedia.org/wiki/Henry_Vandyke_Carter
# Scraping (depth 4): https://en.wikipedia.org/wiki/Surgeon
# Scraping (depth 3): https://en.wikipedia.org/wiki/Bible
# Scraping (depth 1): https://en.wikipedia.org/wiki/Great_wings_of_the_sphenoid
# Graph created with 3248 nodes and 4663 edges.

# %%
nx.write_gml(graph, "wikipedia_network.gml")

# %%
print(graph)
# Out:
# Graph with 3248 nodes and 4663 edges

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
pos = nx.spring_layout(graph, k=0.3)  # Layout algorithm
nx.draw(
    graph, pos,
    with_labels=True,
    node_size=50,
    font_size=7,
    alpha=0.8,
    edge_color='gray'
)
plt.title("Wikipedia Link Network (2 Levels)")
plt.show()

# %%
degree_centrality = nx.degree_centrality(graph)
top_pages = sorted(degree_centrality.items(), key=lambda x: -x[1])[:5]

print("Most connected pages:")
for page, score in top_pages:
    print(f"{page} (Score: {score:.2f})")
# Out:
# Most connected pages:
# Carbon_dioxide (Score: 0.10)
# Jurassic (Score: 0.07)
# Apocrita (Score: 0.05)
# Human_brain (Score: 0.03)
# Human (Score: 0.03)
